# %% [markdown]
# # 作业

# %% [markdown]
# ## 1, 在键盘输入一个整数, 判断给数字能否被2和3同时整除, 能否被2整除, 能否被3整除, 不能被2和3整除的相关信息

# %%
num = input("请输入一个数字: ")

_, res_2 = divmod(int(num), 2)
_, res_3 = divmod(int(num), 3)

if res_2 == 0 and res_3 == 0:
    print(f"{num} 同时被2和3整除")
elif res_2 == 0 and res_3 != 0:
    print(f"{num} 只能被2整除")
elif res_3 == 0:
    print(f"{num} 只能被3整除")
    
else:
    print("不能被2和3整除")
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-3-647ae2e01606> in <module>
# ----> 1 num = input("请输入一个数字: ")
#       2
#       3 _, res_2 = divmod(int(num), 2)
#       4 _, res_3 = divmod(int(num), 3)
#       5
#
# ~/anaconda3/envs/data/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     852         if not self._allow_stdin:
#     853             raise StdinNotImplementedError(
# --> 854                 "raw_input was called, but this frontend does not support input requests."
#     855             )
#     856         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %% [markdown]
# ## 2, 实现用户输入用户名和密码, 当用户名为seven切密码为123时, 显示登陆成功,失败时允许重复输入三次

# %%
user_name = 'seven'
password = '123'

for _ in range(3):
    input_user_name = input("Account: ")
    input_password = input("Password: ")
    
    if input_user_name == user_name and input_password == password:
        print("登陆成功")
        break
    else:
        print("用户名或密码错误!")
else:
    print("失败次数过多")
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-4-2c0a7fd06238> in <module>
#       3
#       4 for _ in range(3):
# ----> 5     input_user_name = input("Account: ")
#       6     input_password = input("Password: ")
#       7
#
# ~/anaconda3/envs/data/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     852         if not self._allow_stdin:
#     853             raise StdinNotImplementedError(
# --> 854                 "raw_input was called, but this frontend does not support input requests."
#     855             )
#     856         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %% [markdown]
# ## 3,使用for...range实现输出1-2+3-4...+99

# %%
all_sum = 0
for i in range(1, 100):
    if i % 2 == 0:
        all_sum -= i
        continue
    all_sum += i
print(all_sum)
# Out:
# 50

# %%
all_sum = sum([i for i in range(1, 100, 2)]) - sum([i for i in range(2, 100, 2)])
print(all_sum)
# Out:
# 50

# %% [markdown]
# ## 4, for循环和while循环打印99乘法表

# %%
for i in range(1, 10):
    for j in range(1, i + 1):
        print(f"{i} * {j} = {i * j}  ", end="")
    else:
        print("")
# Out:
# 1 * 1 = 1
# 2 * 1 = 2  2 * 2 = 4
# 3 * 1 = 3  3 * 2 = 6  3 * 3 = 9
# 4 * 1 = 4  4 * 2 = 8  4 * 3 = 12  4 * 4 = 16
# 5 * 1 = 5  5 * 2 = 10  5 * 3 = 15  5 * 4 = 20  5 * 5 = 25
# 6 * 1 = 6  6 * 2 = 12  6 * 3 = 18  6 * 4 = 24  6 * 5 = 30  6 * 6 = 36
# 7 * 1 = 7  7 * 2 = 14  7 * 3 = 21  7 * 4 = 28  7 * 5 = 35  7 * 6 = 42  7 * 7 = 49
# 8 * 1 = 8  8 * 2 = 16  8 * 3 = 24  8 * 4 = 32  8 * 5 = 40  8 * 6 = 48  8 * 7 = 56  8 * 8 = 64
# 9 * 1 = 9  9 * 2 = 18  9 * 3 = 27  9 * 4 = 36  9 * 5 = 45  9 * 6 = 54  9 * 7 = 63  9 * 8 = 72  9 * 9 = 81

# %%
i = 1

while i <= 9:
    j = i
    while j > 0:
        print(f"{i} * {j} = {i * j} ", end="")
        j -= 1
    else:
        i += 1
        print("")
# Out:
# 1 * 1 = 1
# 2 * 2 = 4 2 * 1 = 2
# 3 * 3 = 9 3 * 2 = 6 3 * 1 = 3
# 4 * 4 = 16 4 * 3 = 12 4 * 2 = 8 4 * 1 = 4
# 5 * 5 = 25 5 * 4 = 20 5 * 3 = 15 5 * 2 = 10 5 * 1 = 5
# 6 * 6 = 36 6 * 5 = 30 6 * 4 = 24 6 * 3 = 18 6 * 2 = 12 6 * 1 = 6
# 7 * 7 = 49 7 * 6 = 42 7 * 5 = 35 7 * 4 = 28 7 * 3 = 21 7 * 2 = 14 7 * 1 = 7
# 8 * 8 = 64 8 * 7 = 56 8 * 6 = 48 8 * 5 = 40 8 * 4 = 32 8 * 3 = 24 8 * 2 = 16 8 * 1 = 8
# 9 * 9 = 81 9 * 8 = 72 9 * 7 = 63 9 * 6 = 54 9 * 5 = 45 9 * 4 = 36 9 * 3 = 27 9 * 2 = 18 9 * 1 = 9

# %% [markdown]
# ## 5, 有1,2,3,4组成互不相同的三位数字

# %%
# 三个数字组合数字
for i in range(1, 5):
    for j in range(1, 5):
        for x in range(1, 5):
            if i != j and i != x and x !=  j:
                print(i, j, x)
# Out:
# 1 2 3
# 1 2 4
# 1 3 2
# 1 3 4
# 1 4 2
# 1 4 3
# 2 1 3
# 2 1 4
# 2 3 1
# 2 3 4
# 2 4 1
# 2 4 3
# 3 1 2
# 3 1 4
# 3 2 1
# 3 2 4
# 3 4 1
# 3 4 2
# 4 1 2
# 4 1 3
# 4 2 1
# 4 2 3
# 4 3 1
# 4 3 2
